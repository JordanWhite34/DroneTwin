# %%
import open3d as o3d

# Load your point cloud
pcd = o3d.io.read_point_cloud(r"..\data\processed\dense\fused-keep-more-cleaned.ply")

# Optional: print basic info
print(pcd)

# View it
o3d.visualization.draw_geometries([pcd])
# Out:
# PointCloud with 886300 points.
